# %% [markdown]
# # Simple Object Detection in Tensorflow
#
# <a target="_blank" href="https://colab.research.google.com/github/LuisAngelMendozaVelasco/TensorFlow-Advanced_Techniques_Specialization/blob/master/Advanced_Computer_Vision_with_TensorFlow/Week2/Labs/C3_W2_Lab_1_Simple_Object_Detection.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png">Run in Google Colab</a>
#
# This lab will walk you through how to use object detection models available in [Tensorflow Hub](https://www.tensorflow.org/hub). In the following sections, you will:
#
# * explore the Tensorflow Hub for object detection models
# * load the models in your workspace
# * preprocess an image for inference
# * run inference on the models and inspect the output
#
# Let's get started!

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import tensorflow_hub as hub
from PIL import Image, ImageOps
import tempfile
from six.moves.urllib.request import urlopen
from six import BytesIO
# Out:
# 2024-08-29 16:42:11.916284: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-29 16:42:11.929186: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-29 16:42:11.932766: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-29 16:42:11.941789: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Download the model from Tensorflow Hub
#
# Tensorflow Hub is a repository of trained machine learning models which you can reuse in your own projects.
# - You can see the domains covered [here](https://tfhub.dev/) and its subcategories.
# - For this lab, you will want to look at the [image object detection subcategory](https://tfhub.dev/s?module-type=image-object-detection).
# - You can select a model to see more information about it and copy the URL so you can download it to your workspace.
# - We selected a [inception resnet version 2](https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1)
# - You can also modify this following cell to choose the other model that we selected, [ssd mobilenet version 2](https://tfhub.dev/tensorflow/ssd_mobilenet_v2/2)

# %%
# You can switch the commented lines here to pick the other model

# Inception resnet version 2
module_handle = "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1"

# You can choose ssd mobilenet version 2 instead and compare the results
# module_handle = "https://tfhub.dev/google/openimages_v4/ssd/mobilenet_v2/1"

# %% [markdown]
# #### Load the model
#
# Next, you'll load the model specified by the `module_handle`.
# - This will take a few minutes to load the model.

# %%
model = hub.load(module_handle)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# 2024-08-29 16:42:21.667018: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2018 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# #### Choose the default signature
#
# Some models in the Tensorflow hub can be used for different tasks. So each model's documentation should show what *signature* to use when running the model.
# - If you want to see if a model has more than one signature then you can do something like `print(hub.load(module_handle).signatures.keys())`. In your case, the models you will be using only have the `default` signature so you don't have to worry about other types.

# %%
# Take a look at the available signatures for this particular model
model.signatures.keys()
# Out:
# KeysView(_SignatureMap({'default': <ConcreteFunction () -> Dict[['detection_class_entities', TensorSpec(shape=(None, 1), dtype=tf.string, name=None)], ['detection_class_names', TensorSpec(shape=(None, 1), dtype=tf.string, name=None)], ['detection_boxes', TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)], ['detection_class_labels', TensorSpec(shape=(None, 1), dtype=tf.int64, name=None)], ['detection_scores', TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]] at 0x70CCEA4DB980>}))

# %% [markdown]
# Please choose the 'default' signature for your object detector.
# - For object detection models, its 'default' signature will accept a batch of image tensors and output a dictionary describing the objects detected, which is what you'll want here.

# %%
detector = model.signatures['default']

# %% [markdown]
# ### download_and_resize_image
#
# This function downloads an image specified by a given "url", pre-processes it, and then saves it to disk.

# %%
def download_and_resize_image(url, new_width=256, new_height=256):
    '''
    Fetches an image online, resizes it and saves it locally.

    Args:
        url (string) -- link to the image
        new_width (int) -- size in pixels used for resizing the width of the image
        new_height (int) -- size in pixels used for resizing the length of the image

    Returns:
        (string) -- path to the saved image
    '''

    # Create a temporary file ending with ".jpg"
    _, filename = tempfile.mkstemp(suffix=".jpg")

    # Opens the given URL
    response = urlopen(url)

    # Reads the image fetched from the URL
    image_data = response.read()

    # Puts the image data in memory buffer
    image_data = BytesIO(image_data)

    # Opens the image
    pil_image = Image.open(image_data)

    # Resizes the image. will crop if aspect ratio is different.
    pil_image = ImageOps.fit(pil_image, (new_width, new_height), Image.LANCZOS)

    # Converts to the RGB colorspace
    pil_image_rgb = pil_image.convert("RGB")

    # Saves the image to the temporary file created earlier
    pil_image_rgb.save(filename, format="JPEG", quality=90)

    print("Image downloaded to %s." % filename)

    return filename

# %% [markdown]
# ### Download and preprocess an image
#
# Now, using `download_and_resize_image` you can get a sample image online and save it locally.
# - We've provided a URL for you, but feel free to choose another image to run through the object detector.
# - You can use the original width and height of the image but feel free to modify it and see what results you get.

# %%
# You can choose a different URL that points to an image of your choice
image_url = "https://upload.wikimedia.org/wikipedia/commons/f/fb/20130807_dublin014.JPG"

# Download the image and use the original height and width
downloaded_image_path = download_and_resize_image(image_url, 3872, 2592)
# Out:
# Image downloaded to /tmp/tmpk3ftl3ad.jpg.

# %% [markdown]
# ### run_detector
#
# This function will take in the object detection model `detector` and the path to a sample image, then use this model to detect objects and display its predicted class categories and detection boxes.
# - run_detector uses `load_image` to convert the image into a tensor.

# %%
def load_img(path):
    '''
    Loads a JPEG image and converts it to a tensor.

    Args:
        path (string) -- path to a locally saved JPEG image

    Returns:
        (tensor) -- an image tensor
    '''

    # Read the file
    img = tf.io.read_file(path)

    # Convert to a tensor
    img = tf.image.decode_jpeg(img, channels=3)

    return img

def run_detector(detector, path):
    '''
    Runs inference on a local file using an object detection model.

    Args:
        detector (model) -- an object detection model loaded from TF Hub
        path (string) -- path to an image saved locally
    '''

    # Load an image tensor from a local file path
    img = load_img(path)

    # Add a batch dimension in front of the tensor
    converted_img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]

    # Run inference using the model
    result = detector(converted_img)

    # Save the results in a dictionary
    result = {key:value.numpy() for key,value in result.items()}

    # Print results
    print("Found %d objects." % len(result["detection_scores"]))

    print("\nDetection scores:\n", result["detection_scores"])
    print("\nDetection class entities:\n", result["detection_class_entities"])
    print("\nDetection boxes:\n", result["detection_boxes"])

# %% [markdown]
# ### Run inference on the image
#
# You can run your detector by calling the `run_detector` function. This will print the number of objects found followed by three lists:
#
# * The detection scores of each object found (i.e. how confident the model is),
# * The classes of each object found,
# * The bounding boxes of each object
#
# You will see how to overlay this information on the original image in the next sections and in this week's assignment!

# %%
# Runs the object detection model and prints information about the objects found
run_detector(detector, downloaded_image_path)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1724971384.795000   44323 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -2642 } dim { size: -2643 } dim { size: -2644 } dim { size: 1088 } } } inputs { dtype: DT_FLOAT shape { dim { size: -22 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -22 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 17 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce GTX 1650" frequency: 1515 num_cores: 14 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8907" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 1048576 shared_memory_size_per_multiprocessor: 65536 memory_size: 2116026368 bandwidth: 192032000 } outputs { dtype: DT_FLOAT shape { dim { size: -22 } dim { size: 17 } dim { size: 17 } dim { size: 1088 } } }
# 2024-08-29 16:43:16.204066: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1724971396.257655   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.277339   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.278972   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.280652   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.282325   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.286602   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.288482   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.291150   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.293694   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.295544   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.298079   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.300296   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.302939   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.305205   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.315263   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.343744   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.346416   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.349139   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.352855   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.355992   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.359528   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.362581   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.370246   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.374696   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.378328   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.382338   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.386981   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.392041   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.397666   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.404088   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.412220   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.421057   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.445769   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.448719   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.452425   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.455706   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.459389   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.462594   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.466225   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.470378   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.474638   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.478441   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.482998   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.487926   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.494086   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.499608   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.506965   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.513610   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.539878   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.541406   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.542861   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.544329   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.545792   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.547256   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.548839   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.551078   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.552689   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.554405   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.556616   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.558172   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.559768   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.561603   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.563316   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.565009   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.573146   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.587098   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.591491   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.595793   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.600314   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.605477   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.610140   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.616887   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.622043   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.627679   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.633165   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.640039   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.645293   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.654346   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.663337   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.674397   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.683503   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2024-08-29 16:43:16.703657: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# W0000 00:00:1724971396.707892   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.709511   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.711000   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.712406   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.713808   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.715258   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.717357   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.718765   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.720168   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.721760   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.723787   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.725366   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.726882   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.728371   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.729880   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.731523   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.734912   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.747451   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.748779   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.750874   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.752322   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.753658   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.755095   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.757120   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.758479   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.759897   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.761269   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.762631   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.764126   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.765619   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.767759   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.769286   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.770818   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.772784   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.777281   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.814795   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.816371   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.818128   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.819501   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.820866   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.822396   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.824319   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.825668   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.827071   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.828414   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.829830   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.831313   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.833122   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.834929   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.836466   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.838041   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.840523   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.850761   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.852940   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.854888   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.857777   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.859509   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.862090   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.863905   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.866027   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.868286   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.870135   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.872015   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.874337   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.876436   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.878911   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.881609   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.884403   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.901051   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.902724   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.904396   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.906091   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.907813   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.909454   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.911164   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.912793   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.914464   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.916401   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.918469   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.920124   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.922281   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.924843   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.927014   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.929113   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.932923   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.940690   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.966368   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.968042   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.970048   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.972251   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.974647   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.976477   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.978387   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.980222   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.982079   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.984483   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.986509   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.988463   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.991514   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.993883   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.996496   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971396.998939   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.004107   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.038052   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.039636   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.041421   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.042766   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.044096   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.045467   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.046783   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.048109   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.050068   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.051619   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.053066   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.054692   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.056727   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.058091   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.059621   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.061331   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.065619   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.104643   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.105991   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.107294   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.108590   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.109895   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.111206   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.112517   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.113843   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.115176   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.117210   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.118576   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.119959   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.121441   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.123559   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.125014   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.126586   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.128317   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.130385   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.140574   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.142036   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.143398   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.144756   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.146134   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.147498   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.148878   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.151035   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.152490   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.153892   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.155527   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.157482   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.158990   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.160554   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.161996   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.163576   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.165497   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.168797   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.180349   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.181721   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.183616   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.185027   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.186553   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.187959   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.190312   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.191757   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.193199   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.194645   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.196095   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.197632   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.199493   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.201320   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.203166   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.204821   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.207281   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.211075   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.226632   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.228120   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.229687   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.231189   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.233082   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.235015   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.236726   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.238434   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.240731   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.242369   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.244105   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.245901   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.247719   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.250097   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.252225   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.254111   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.257260   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.323901   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.340015   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.347497   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.357169   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.365432   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.375973   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.385850   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.395538   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.406165   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.416357   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.427910   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.436945   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.451177   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.469927   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.489238   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.507532   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.559157   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.562388   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.564308   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.566395   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.568586   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.570558   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.572716   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.575043   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.576966   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.578886   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.580915   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.583655   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.585876   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.588352   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.591386   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.593897   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.597409   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.630485   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.634888   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.640128   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.644828   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.650167   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.656563   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.661824   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.667701   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.674328   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.679939   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.686526   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.691887   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.698916   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.708847   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.719623   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.729764   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.760617   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.765518   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.773505   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.780007   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.787521   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.795318   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.803098   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.810236   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.818986   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.827972   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.837265   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.844517   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.856671   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.871050   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.886611   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.901445   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.949593   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.952390   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.955360   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.958449   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.961092   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.963834   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.967100   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.970324   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.973899   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.976827   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.979837   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.984273   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.988583   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.993166   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971397.997247   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.002385   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2024-08-29 16:43:18.008176: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.73GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# W0000 00:00:1724971398.012364   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.014472   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.017701   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.020309   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.022752   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.025480   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.027741   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.029778   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.032132   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.035190   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.037741   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.041665   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.044344   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.047428   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.051257   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.055447   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2024-08-29 16:43:18.060510: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.54GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# W0000 00:00:1724971398.064610   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.067594   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.070271   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.072851   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.075608   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.077830   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.080175   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.082807   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.085476   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.087896   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.092229   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971398.095442   44429 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# ...
# W0000 00:00:1724971402.152402   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.167075   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.182377   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.196804   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.214331   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.278298   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.291759   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.295175   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.298898   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.302723   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.306093   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.310053   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.313729   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.318182   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.322080   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.330965   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.336535   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.342817   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.349062   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.355597   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.369864   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.374312   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.383423   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.387448   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.392129   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.395980   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.400881   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.405267   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.409551   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.414027   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.418318   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.425617   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.430787   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.438628   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.446515   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.463010   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.478699   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.495034   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.512006   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.530926   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.550984   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.572884   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.594226   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.620373   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.647954   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.671576   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.694978   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.720348   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.755405   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.790922   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.824690   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971402.951122   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.415085   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.471497   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.536159   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.600875   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.659100   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.747916   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.835501   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.904863   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971403.976658   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971404.049783   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971404.114797   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971404.204717   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1724971404.321289   44433 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# Found 100 objects.
#
# Detection scores:
#  [0.65448576 0.6114539  0.6042274  0.59263176 0.5921922  0.58049124
#  0.5514052  0.4946692  0.47515702 0.47342214 0.43995938 0.4148516
#  0.40629733 0.3982894  0.397653   0.37621075 0.37279427 0.36574844
#  0.35260734 0.33274773 0.30428663 0.2727656  0.26865074 0.25777173
#  0.25290567 0.24612108 0.23403783 0.20342937 0.18229423 0.1804577
#  0.17571369 0.16435082 0.15849963 0.15665978 0.15470928 0.15452768
#  0.14924915 0.13340692 0.12948267 0.12649699 0.12044197 0.11767332
#  0.11356067 0.11114843 0.11100272 0.1091493  0.10604016 0.0894051
#  0.08598321 0.08280165 0.08104508 0.07806055 0.07760363 0.07628626
#  0.07546864 0.0744413  0.07427155 0.07204875 0.07177526 0.07102234
#  0.07032738 0.06809694 0.06304476 0.06285913 0.0627095  0.06223931
#  0.05882135 0.05815005 0.05795752 0.05787573 0.05462372 0.05274337
#  0.05133702 0.0482655  0.04708424 0.04682794 0.04495208 0.04405155
#  0.0436071  0.04113495 0.0410996  0.03968572 0.03934988 0.03912779
#  0.03879521 0.03878608 0.03739633 0.03606932 0.033671   0.03366862
#  0.03260196 0.03253522 0.0320149  0.02983097 0.02877984 0.02867624
#  0.02803954 0.02783183 0.02734369 0.02668224]
#
# Detection class entities:
#  [b'Person' b'Person' b'Person' b'Person' b'Footwear' b'Person' b'Building'
#  b'Bicycle' b'Building' b'Window' b'Person' b'Bicycle' b'Wheel'
#  b'Building' b'Building' b'Building' b'Person' b'Wheel' b'Window'
#  b'Window' b'Building' b'Person' b'Van' b'Person' b'Bicycle wheel'
#  b'Person' b'Window' b'Window' b'Building' b'Window' b'Window' b'Man'
#  b'Person' b'Woman' b'Person' b'Clothing' b'Bicycle wheel' b'Window'
#  b'Person' b'Window' b'Land vehicle' b'Land vehicle' b'Clothing' b'Window'
#  b'Bicycle' b'Land vehicle' b'House' b'House' b'Man' b'Window' b'Clothing'
#  b'Window' b'Footwear' b'Person' b'Man' b'Man' b'House' b'Building'
#  b'Person' b'Clothing' b'Window' b'Person' b'Man' b'Person' b'Furniture'
#  b'Jeans' b'Person' b'Person' b'Person' b'Land vehicle' b'Window' b'House'
#  b'Woman' b'Man' b'Window' b'Person' b'Person' b'Clothing' b'Man' b'Man'
#  b'Window' b'Car' b'Person' b'Man' b'Chair' b'Car' b'House' b'Window'
#  b'Tire' b'Clothing' b'Window' b'Clothing' b'Land vehicle' b'Window'
#  b'Window' b'Man' b'Van' b'Bus' b'Clothing' b'Car']
#
# Detection boxes:
#  [[5.1279444e-01 5.2927095e-01 6.0166234e-01 5.5209446e-01]
#  [5.1974601e-01 6.0150713e-01 6.4612418e-01 6.3468289e-01]
#  [5.0574601e-01 5.0044078e-01 6.0134917e-01 5.2308965e-01]
#  [4.8630881e-01 4.1276225e-01 6.7855030e-01 4.5990565e-01]
#  [8.1519085e-01 9.5611840e-01 8.4270173e-01 9.8714471e-01]
#  [4.9546641e-01 9.2353427e-01 8.3563489e-01 9.9905688e-01]
#  [1.1098582e-02 1.1912006e-02 7.3975050e-01 4.2490715e-01]
#  [5.7782602e-01 3.6645326e-01 7.1280569e-01 4.8333818e-01]
#  [7.7493593e-02 4.1305405e-01 5.7945877e-01 5.6030917e-01]
#  [0.0000000e+00 1.1929259e-01 2.2389720e-01 1.8394905e-01]
#  [5.1406974e-01 7.4809784e-01 5.9196222e-01 7.6656920e-01]
#  [5.7077783e-01 3.6182037e-01 7.0732844e-01 4.2966676e-01]
#  [6.3209409e-01 3.5986990e-01 7.0384175e-01 4.1181558e-01]
#  [1.5908534e-02 6.8496162e-01 5.5938894e-01 8.1114680e-01]
#  [0.0000000e+00 7.9710943e-01 6.7373610e-01 1.0000000e+00]
#  [0.0000000e+00 2.1702699e-01 6.5097320e-01 4.3200094e-01]
#  [5.0037277e-01 3.7700447e-01 6.3335049e-01 4.1451439e-01]
#  [6.4033997e-01 4.4502339e-01 7.0303476e-01 4.8345748e-01]
#  [1.9440461e-03 0.0000000e+00 1.3933197e-01 2.6288422e-02]
#  [2.5519053e-03 9.6662557e-01 1.5375262e-01 1.0000000e+00]
#  [1.4155833e-03 1.4104844e-03 7.6484823e-01 2.6935190e-01]
#  [5.0490111e-01 3.6078489e-01 6.3766336e-01 3.8548014e-01]
#  [4.8338374e-01 6.1948407e-01 5.6265807e-01 6.6157198e-01]
#  [4.9820140e-01 3.6461410e-01 6.6115755e-01 4.0489641e-01]
#  [6.3122934e-01 3.6032289e-01 7.0414704e-01 4.1149938e-01]
#  [5.2180678e-01 5.7769489e-01 5.8761311e-01 6.0071784e-01]
#  [2.1960370e-01 3.4873888e-01 3.3825555e-01 3.7706766e-01]
#  [1.2482674e-01 2.5092393e-01 2.7991483e-01 2.8162587e-01]
#  [2.5731847e-01 5.6749362e-01 5.3091002e-01 6.8787658e-01]
#  [4.2175382e-02 8.7476528e-01 2.5286338e-01 9.1304618e-01]
#  [1.5640162e-01 4.4336551e-01 2.2223385e-01 4.7578454e-01]
#  [5.0199443e-01 9.2146742e-01 8.3636171e-01 1.0000000e+00]
#  [5.2367359e-01 5.7034701e-01 5.8450621e-01 5.9160703e-01]
#  [5.1916909e-01 5.9996605e-01 6.4633018e-01 6.3409466e-01]
#  [5.1315480e-01 6.7922854e-01 5.5098128e-01 6.9254810e-01]
#  [5.2434462e-01 9.2494547e-01 8.1052816e-01 9.9797946e-01]
#  [6.3806325e-01 4.4279727e-01 7.0172912e-01 4.8413196e-01]
#  [3.4105543e-02 3.5565761e-01 1.6230486e-01 3.7490875e-01]
#  [4.8809028e-01 4.5336694e-01 6.2225717e-01 4.7966492e-01]
#  [9.6649490e-04 3.0770731e-01 1.0651586e-01 3.3207035e-01]
#  [4.8297009e-01 6.1979163e-01 5.6477898e-01 6.6065258e-01]
#  [5.8239120e-01 3.6492342e-01 7.1389169e-01 4.8468536e-01]
#  [5.2378994e-01 7.4929273e-01 5.8547032e-01 7.6531148e-01]
#  [3.5146436e-01 9.7486877e-01 5.5304360e-01 9.9888706e-01]
#  [6.0907686e-01 4.2683351e-01 7.0519632e-01 4.8710752e-01]
#  [5.6925470e-01 3.5978299e-01 7.0856631e-01 4.2843869e-01]
#  [0.0000000e+00 8.1118721e-01 6.9358277e-01 9.9325359e-01]
#  [1.0429484e-02 2.2946956e-02 7.2731256e-01 4.2228740e-01]
#  [4.8463228e-01 4.1069779e-01 6.9474274e-01 4.6313992e-01]
#  [8.1154458e-02 3.8477594e-01 2.0795213e-01 4.1175538e-01]
#  [5.3856730e-01 6.0358500e-01 6.3474083e-01 6.3447654e-01]
#  [0.0000000e+00 1.2407589e-02 1.4029649e-01 2.4734123e-02]
#  [6.2977993e-01 6.1488342e-01 6.4490789e-01 6.2533504e-01]
#  [5.0284290e-01 3.8242072e-01 5.9601647e-01 4.1271874e-01]
#  [5.1468146e-01 7.4787104e-01 5.9194779e-01 7.6678252e-01]
#  [5.0643325e-01 5.0040275e-01 6.0071695e-01 5.2331966e-01]
#  [0.0000000e+00 2.1112861e-01 6.5082580e-01 4.3438429e-01]
#  [0.0000000e+00 7.0632064e-01 6.1716139e-01 8.6594027e-01]
#  [4.8929811e-01 4.5427489e-01 5.7262003e-01 4.7639754e-01]
#  [5.0920737e-01 4.1626489e-01 6.6901666e-01 4.5957711e-01]
#  [4.6780333e-03 8.0310702e-01 1.5958229e-01 8.4036517e-01]
#  [5.2617568e-01 5.6837583e-01 5.7943624e-01 5.8280301e-01]
#  [5.0284749e-01 3.7398589e-01 6.4712596e-01 4.1297257e-01]
#  [4.8591751e-01 4.4443727e-01 6.2469023e-01 4.7351983e-01]
#  [5.7416862e-01 2.6725131e-01 6.5776157e-01 3.2031402e-01]
#  [6.7198223e-01 9.4031775e-01 8.2117718e-01 9.8921400e-01]
#  [5.2410471e-01 5.6155598e-01 5.7834709e-01 5.8050251e-01]
#  [5.1758975e-01 7.5722069e-01 5.8831394e-01 7.7154583e-01]
#  [5.2332854e-01 5.5781382e-01 5.7902890e-01 5.7355350e-01]
#  [6.1236000e-01 4.2740157e-01 7.0609623e-01 4.8830026e-01]
#  [0.0000000e+00 2.4423711e-01 6.0888749e-02 2.9377386e-01]
#  [1.5484340e-02 1.9419364e-03 7.4516350e-01 2.5933647e-01]
#  [4.9326646e-01 9.2395955e-01 8.3691311e-01 9.9770677e-01]
#  [5.0529295e-01 3.6016640e-01 6.4336234e-01 3.9143845e-01]
#  [8.4342277e-03 2.4212143e-01 4.9744956e-02 2.8314558e-01]
#  [5.2210921e-01 5.3608811e-01 5.9767491e-01 5.5313313e-01]
#  [5.1312602e-01 5.2381009e-01 6.0054040e-01 5.4296505e-01]
#  [5.1831567e-01 5.0345343e-01 5.9754533e-01 5.2275288e-01]
#  [5.2045572e-01 6.0093164e-01 6.4599115e-01 6.3436383e-01]
#  [5.1316828e-01 6.7925382e-01 5.5048609e-01 6.9244283e-01]
#  [4.2972320e-01 8.2874358e-01 5.9004873e-01 8.6437541e-01]
#  [5.2659333e-01 6.2719083e-01 5.6328988e-01 6.5378499e-01]
#  [5.0478113e-01 3.8941064e-01 6.1523122e-01 4.1995159e-01]
#  [5.0132489e-01 3.6423624e-01 6.5975285e-01 4.0371999e-01]
#  [5.7311022e-01 2.6673263e-01 6.6622353e-01 3.1864992e-01]
#  [5.1510340e-01 6.2409180e-01 5.6383228e-01 6.5803182e-01]
#  [8.3203204e-02 4.0756792e-01 5.8434409e-01 5.5831051e-01]
#  [2.8820193e-01 4.6254057e-04 4.1427991e-01 3.6707688e-02]
#  [6.2713271e-01 3.6099508e-01 7.0596063e-01 4.0978041e-01]
#  [4.9715948e-01 4.5521107e-01 5.8427131e-01 4.7787207e-01]
#  [1.1719427e-02 3.0807254e-01 9.7320050e-02 3.2507548e-01]
#  [5.1589394e-01 3.8009039e-01 5.9697241e-01 4.1176715e-01]
#  [5.1242912e-01 6.2364930e-01 5.6243664e-01 6.5768224e-01]
#  [4.0077379e-01 8.8497424e-01 5.8165658e-01 9.3913031e-01]
#  [0.0000000e+00 9.9475970e-03 1.3625401e-01 3.1597443e-02]
#  [5.1390564e-01 5.2950239e-01 6.0205597e-01 5.5237609e-01]
#  [5.1069164e-01 6.2403965e-01 5.6341004e-01 6.5817988e-01]
#  [4.8037991e-01 6.2032777e-01 5.6528419e-01 6.6012335e-01]
#  [5.3840739e-01 9.2802435e-01 7.1361756e-01 9.9945277e-01]
#  [4.8633781e-01 6.2024730e-01 5.6352878e-01 6.6021770e-01]]
