# %% [markdown]
# # Ungraded Lab: Saliency
#
# <a target="_blank" href="https://colab.research.google.com/github/LuisAngelMendozaVelasco/TensorFlow-Advanced_Techniques_Specialization/blob/master/Advanced_Computer_Vision_with_TensorFlow/Week4/Labs/C3_W4_Lab_3_Saliency.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png">Run in Google Colab</a>
#
# Like class activation maps, saliency maps also tells us what parts of the image the model is focusing on when making its predictions.
# - The main difference is in saliency maps, we are just shown the relevant pixels instead of the learned features.
# - You can generate saliency maps by getting the gradient of the loss with respect to the image pixels.
# - This means that changes in certain pixels that strongly affect the loss will be shown brightly in your saliency map.
#
# Let's see how this is implemented in the following sections.

# %%
# Install packages for compatibility

# NOTE: You can safely ignore errors about version incompatibility of
# Colab-bundled packages (e.g. xarray, pydantic, etc.)

# !pip install tf-keras==2.15 --quiet
# !pip install tensorflow==2.15 --quiet
# !pip install keras==2.15 --quiet

# %% [markdown]
# ## Imports

# %%
# %tensorflow_version 2.x

import tensorflow as tf
import tensorflow_hub as hub
from keras import layers, losses
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Build the model
#
# For the classifier, you will use the [Inception V3 model](https://arxiv.org/abs/1512.00567) available in [Tensorflow Hub](https://tfhub.dev/google/tf2-preview/inception_v3/classification/4). This has pre-trained weights that is able to detect 1001 classes. You can read more [here](https://tfhub.dev/google/tf2-preview/inception_v3/classification/4).

# %%
# Grab the model from Tensorflow hub and append a softmax activation
model = tf.keras.Sequential([layers.Lambda(lambda x: hub.KerasLayer('https://tfhub.dev/google/tf2-preview/inception_v3/classification/4')(x)),
                             layers.Activation('softmax')])

# Build the model based on a specified batch input shape
model.build([None, 300, 300, 3])

# %% [markdown]
# ## Get a sample image
#
# You will download a photo of a Siberian Husky that our model will classify. We left the option to download a Tabby Cat image instead if you want.

# %%
# !wget -O ./image.jpg https://cdn.pixabay.com/photo/2018/02/27/14/11/the-pacific-ocean-3185553_960_720.jpg

# If you want to try the cat, uncomment this line
# !wget -O image.jpg https://cdn.pixabay.com/photo/2018/02/27/14/11/the-pacific-ocean-3185553_960_720.jpg
# Out:
# --2024-09-10 17:23:53--  https://cdn.pixabay.com/photo/2018/02/27/14/11/the-pacific-ocean-3185553_960_720.jpg
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving cdn.pixabay.com (cdn.pixabay.com)... 104.18.40.96, 172.64.147.160, 2606:4700:4400::6812:2860, ...
# Connecting to cdn.pixabay.com (cdn.pixabay.com)|104.18.40.96|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 212830 (208K) [binary/octet-stream]
# Saving to: ‘./image.jpg’
#
# ./image.jpg         100%[===================>] 207.84K  --.-KB/s    in 0.1s
#
# 2024-09-10 17:23:53 (1.40 MB/s) - ‘./image.jpg’ saved [212830/212830]

# %% [markdown]
# ## Preprocess the image
#
# The image needs to be preprocessed before being fed to the model. This is done in the following steps:

# %%
# Read the image
img = cv2.imread('./image.jpg')

# Format it to be in the RGB colorspace
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Resize to 300x300 and normalize pixel values to be in the range [0, 1]
img = cv2.resize(img, (300, 300)) / 255.0

# Add a batch dimension in front
image = np.expand_dims(img, axis=0)

# %% [markdown]
# We can now preview our input image.

# %%
plt.figure(figsize=(8, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Compute Gradients
#
# You will now get the gradients of the loss with respect to the input image pixels. This is the key step to generate the map later.

# %%
# Siberian Husky's class ID in ImageNet
class_index = 251

# If you downloaded the cat, use this line instead
# class_index = 282   # Tabby Cat in ImageNet

# Number of classes in the model's training data
num_classes = 1001

# Convert to one hot representation to match our softmax activation in the model definition
expected_output = tf.one_hot([class_index] * image.shape[0], num_classes)

with tf.GradientTape() as tape:
    # Cast image to float
    inputs = tf.cast(image, tf.float32)

    # Watch the input pixels
    tape.watch(inputs)

    # Generate the predictions
    predictions = model(inputs)

    # Get the loss
    loss = losses.categorical_crossentropy(expected_output, predictions)

# Get the gradient with respect to the inputs
gradients = tape.gradient(loss, inputs)
# Out:
# 2024-09-10 17:26:19.711829: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90201
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1726010779.768172   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.797406   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.799408   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.801386   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.805474   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.807022   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.808783   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.810871   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.812668   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.815265   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.817726   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.819315   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.820979   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.838846   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.840595   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.842580   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.844829   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.846737   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.848462   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.855848   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.857706   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.867349   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.872870   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.874684   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.877353   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.879404   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.881325   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.884361   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2024-09-10 17:26:19.886615: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 548.16MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# W0000 00:00:1726010779.886673   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.889814   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.898283   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.901070   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.902994   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.905401   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.907323   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.910099   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.912108   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.914306   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.917425   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.919443   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.921668   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.924028   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.927098   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.931253   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.936164   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2024-09-10 17:26:19.944311: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.04GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# W0000 00:00:1726010779.959720   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.961372   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.963512   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.965031   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.967678   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.969210   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.970684   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.972160   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.973653   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.975149   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.977460   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.979013   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.980699   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.982680   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.984777   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.989701   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.991657   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.994528   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.997139   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010779.999812   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.002784   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.004949   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.007424   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.010498   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.012954   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.015129   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.017728   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.020020   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.022457   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.024507   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.031407   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2024-09-10 17:26:20.041291: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.93GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# W0000 00:00:1726010780.043432   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.044699   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.046137   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.047434   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.049026   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.050704   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.051965   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.053218   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.054474   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.055719   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.056977   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.058242   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.060207   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.061518   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.063122   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.067320   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.068661   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.069923   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.071168   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.072401   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.073657   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.074894   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.076845   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.078147   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.079556   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.080870   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.082444   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.084065   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.085405   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.087008   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.116074   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.117375   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.118587   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.119838   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.121074   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.122309   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.123550   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.124816   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.126782   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.128081   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.129952   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.131247   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.133420   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.134913   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.141172   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.143238   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.144591   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.146115   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.147517   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.149183   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.150990   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.152333   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.153720   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.155158   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.156583   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.157971   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.160459   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.162304   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.164354   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.167910   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.172345   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.173665   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.174975   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.177019   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.178377   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.179887   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.181244   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.183259   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.184580   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.185911   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.187226   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.188583   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.189976   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.191410   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.194030   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.196764   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.199145   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.205856   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.207203   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.208772   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.210646   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.212091   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.213620   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.214986   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.217033   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.218400   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.219764   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.221118   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.222542   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.223986   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.225745   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.228425   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.231561   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.234685   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.241953   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.243277   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.244535   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.245973   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780.247286   15929 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010780
15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.695169   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.697317   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.699222   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.701201   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.703077   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.706312   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.707795   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.710308   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.712328   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.714479   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.717071   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.719520   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.722481   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.725640   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.733866   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.735553   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.737533   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.739493   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.741525   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.744164   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.746539   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.749043   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.751669   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.754442   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.757010   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.760677   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.770174   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.771600   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.773175   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.775712   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.778499   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.780328   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.782535   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.784798   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.786693   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.791074   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.793405   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.795025   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.797157   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.799295   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.801934   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.803618   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.805504   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.808071   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.810726   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.816191   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.817830   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.819130   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.820653   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.822100   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.823691   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.825495   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.827501   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.829307   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.832489   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.833963   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.835306   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.848067   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.851411   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.857622   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1726010783.860461   15926 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced

# %% [markdown]
# ## Visualize the results
#
# Now that you have the gradients, you will do some postprocessing to generate the saliency maps and overlay it on the image.

# %%
# Reduce the RGB image to grayscale
grayscale_tensor = tf.reduce_sum(tf.abs(gradients), axis=-1)

# Normalize the pixel values to be in the range [0, 255].
# The max value in the grayscale tensor will be pushed to 255.
# The min value will be pushed to 0.
normalized_tensor = tf.cast(255 * (grayscale_tensor - tf.reduce_min(grayscale_tensor))
                            / (tf.reduce_max(grayscale_tensor) - tf.reduce_min(grayscale_tensor)), tf.uint8,)

# Remove the channel dimension to make the tensor a 2d tensor
normalized_tensor = tf.squeeze(normalized_tensor)

# %% [markdown]
# Let's do a little sanity check to see the results of the conversion.

# %%
# Max and min value in the grayscale tensor
print(np.max(grayscale_tensor[0]))
print(np.min(grayscale_tensor[0]))
print()

# Coordinates of the first pixel where the max and min values are located
max_pixel = np.unravel_index(np.argmax(grayscale_tensor[0]), grayscale_tensor[0].shape)
min_pixel = np.unravel_index(np.argmin(grayscale_tensor[0]), grayscale_tensor[0].shape)
print(max_pixel)
print(min_pixel)
print()

# These coordinates should have the max (255) and min (0) value in the normalized tensor
print(normalized_tensor[max_pixel])
print(normalized_tensor[min_pixel])
# Out:
# 1.085937
# 0.0
#
# (207, 132)
# (0, 299)
#
# tf.Tensor(255, shape=(), dtype=uint8)
# tf.Tensor(0, shape=(), dtype=uint8)

# %% [markdown]
# You should get something like:
#
# ```
# 1.2167013
# 0.0
#
# (203, 129)
# (0, 299)
#
# tf.Tensor(255, shape=(), dtype=uint8)
# tf.Tensor(0, shape=(), dtype=uint8)
# ```

# %% [markdown]
# Now let's see what this looks like when plotted. The white pixels show the parts the model focused on when classifying the image.

# %%
plt.figure(figsize=(8, 8))
plt.axis('off')
plt.imshow(normalized_tensor, cmap='gray')
plt.show()

# %% [markdown]
# Let's superimpose the normalized tensor to the input image to get more context. You can see that the strong pixels are over the husky and that is a good indication that the model is looking at the correct part of the image.

# %%
gradient_color = cv2.applyColorMap(normalized_tensor.numpy(), cv2.COLORMAP_HOT)
gradient_color = gradient_color / 255.0
super_imposed = cv2.addWeighted(img, 0.5, gradient_color, 0.5, 0.0)

plt.figure(figsize=(8, 8))
plt.imshow(super_imposed)
plt.axis('off')
plt.show()

# %%
# !rm ./image.jpg
